# %%
import pandas as pd

# %%
pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\asus\anaconda31\lib\site-packages (from pandas_datareader) (1.4.1)
# Requirement already satisfied: lxml in c:\users\asus\anaconda31\lib\site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\asus\anaconda31\lib\site-packages (from pandas_datareader) (2.25.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda31\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\asus\anaconda31\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\asus\anaconda31\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.22.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\asus\anaconda31\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda31\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\anaconda31\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\asus\anaconda31\lib\site-packages (from requests>=2.19.0->pandas_datareader) (4.0.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as web

# %%
import datetime

# %%
start= datetime.datetime(2012,1,1)

# %%
end= datetime.datetime(2017,1,1)

# %%
path= r"C:\Users\Asus\Downloads\Python-for-Finance-Repo-master\Python-for-Finance-Repo-master\07-Stock-Market-Analysis-Capstone-Project\Ford_Stock.csv"

# %%
ford = pd.read_csv(path)

# %%
ford.head()
# Out:
#          Date   Open   High    Low  Close    Volume
# 0  2012-01-03  11.00  11.25  10.99  11.13  45709811
# 1  2012-01-04  11.15  11.53  11.07  11.30  79725188
# 2  2012-01-05  11.33  11.63  11.24  11.59  67877467
# 3  2012-01-06  11.74  11.80  11.52  11.71  59840605
# 4  2012-01-09  11.83  11.95  11.70  11.80  53981467

# %%
path2= r"C:\Users\Asus\Downloads\Python-for-Finance-Repo-master\Python-for-Finance-Repo-master\07-Stock-Market-Analysis-Capstone-Project\GM_Stock.csv"

# %%
path3= r"C:\Users\Asus\Downloads\Python-for-Finance-Repo-master\Python-for-Finance-Repo-master\07-Stock-Market-Analysis-Capstone-Project\Tesla_Stock.csv"

# %%
tesla= pd.read_csv(path3)

# %%
gm = pd.read_csv(path2)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = [20,10])
plt.plot(gm['Close'], label= 'General Motors')
plt.plot(tesla['Close'], label= 'TESLA')
plt.plot(ford['Close'], label= 'FORD Motors')
plt.legend()

# %%
plt.figure(figsize = [30,30])
plt.plot(gm['Volume'], label= 'General Motors')
plt.plot(tesla['Volume'], label= 'TESLA')
plt.plot(ford['Volume'], label= 'FORD Motors')
plt.legend()

# %%
tesla.head()
# Out:
#          Date   Open   High    Low  Close   Volume
# 0  2012-01-03  28.94  29.50  27.65  28.08   928052
# 1  2012-01-04  28.21  28.67  27.50  27.71   630036
# 2  2012-01-05  27.76  27.93  26.85  27.12  1005432
# 3  2012-01-06  27.20  27.79  26.41  26.89   687081
# 4  2012-01-09  27.00  27.49  26.12  27.25   896951

# %%
tesla['Volume'].max()
# Out:
# 37163898

# %%
tesla['Volume'].argmax()
# Out:
# 341

# %%
tesla.set_index('Date',drop=True, inplace = True)

# %%
ford.set_index('Date',drop=True, inplace = True)
gm.set_index('Date',drop=True, inplace = True)

# %%
tesla['Volume'].argmax()
# Out:
# 341

# %%
tesla.head()
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052
# 2012-01-04  28.21  28.67  27.50  27.71   630036
# 2012-01-05  27.76  27.93  26.85  27.12  1005432
# 2012-01-06  27.20  27.79  26.41  26.89   687081
# 2012-01-09  27.00  27.49  26.12  27.25   896951

# %%
tesla.index = pd.to_datetime(tesla.index)

# %%
tesla.head()
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2012-01-03  28.94  29.50  27.65  28.08   928052
# 2012-01-04  28.21  28.67  27.50  27.71   630036
# 2012-01-05  27.76  27.93  26.85  27.12  1005432
# 2012-01-06  27.20  27.79  26.41  26.89   687081
# 2012-01-09  27.00  27.49  26.12  27.25   896951

# %%
type(tesla.index
    )
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
tesla['Volume'].argmax()
# Out:
# 341

# %%
tesla.index[341]
# Out:
# Timestamp('2013-05-14 00:00:00')

# %%
tesla['Traded Val']= tesla['Open']*tesla['Volume']

# %%
ford['Traded Val']= ford['Open']*ford['Volume']

# %%
gm['Traded Val']= gm['Open']*gm['Volume']

# %%
ford.index = pd.to_datetime(ford.index)
gm.index = pd.to_datetime(gm.index)

# %%
plt.figure(figsize = [30,30])
plt.plot(gm['Traded Val'], label= 'General Motors')
plt.plot(tesla['Traded Val'], label= 'TESLA')
plt.plot(ford['Traded Val'], label= 'FORD Motors')
plt.legend()

# %%
plt.figure(figsize = [30,20])
plt.plot(ford['Open'], label = 'Ford Opening Stock')
plt.plot(ford.rolling(50).mean()['Open'], label= 'Ford 50 Day MA')
plt.plot(ford.rolling(200).mean()['Open'], label = 'Ford 200 Day MA')
plt.legend()

# %%
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df = pd.DataFrame(columns =['Ford Open','GM Open','Tesla Open'] )

# %%
ford.rename({'Open':'Ford Open'}, inplace = True, axis = 1)

# %%
tesla.rename({'Open':'Tesla Open'}, inplace = True, axis = 1)
gm.rename({'Open':'GM Open'}, inplace = True, axis = 1)

# %%
df = pd.concat([ford['Ford Open'],gm['GM Open'],tesla['Tesla Open']], axis = 1)

# %%
df
# Out:
#             Ford Open  GM Open  Tesla Open
# Date
# 2012-01-03      11.00    20.83       28.94
# 2012-01-04      11.15    21.05       28.21
# 2012-01-05      11.33    21.10       27.76
# 2012-01-06      11.74    22.26       27.20
# 2012-01-09      11.83    23.20       27.00
# ...               ...      ...         ...
# 2016-12-23      12.43    35.83      208.00
# 2016-12-27      12.43    35.80      214.88
# 2016-12-28      12.37    35.74      221.53
# 2016-12-29      12.25    35.25      218.56
# 2016-12-30      12.24    35.21      216.30
#
# [1258 rows x 3 columns]

# %%
df.fillna(0, 
          inplace =True, axis =1 )

# %%
sns.pairplot(df)

# %%
import numpy as np

# %%
plt.figure(figsize=[10,20])
plt.plot(100*np.divide(ford['Ford Open']-ford['Ford Open'].shift(1),ford['Ford Open']))

# %%
plt.hist(100*np.divide(ford['Ford Open']-ford['Ford Open'].shift(1),ford['Ford Open']), bins= 10)
# Out:
# (array([  1.,   0.,   2.,   2.,  59., 664., 493.,  33.,   0.,   1.]),
#  array([-16.74836601, -13.91107454, -11.07378306,  -8.23649159,
#          -5.39920011,  -2.56190864,   0.27538284,   3.11267431,
#           5.94996579,   8.78725726,  11.62454874]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=[15,10])

plt.hist(100*np.divide(ford['Ford Open']-ford['Ford Open'].shift(1),ford['Ford Open']), bins= 100, label = 'Ford')

plt.hist(100*np.divide(tesla['Tesla Open']-tesla['Tesla Open'].shift(1),tesla['Tesla Open']), bins= 100, label = 'Tesla')

plt.hist(100*np.divide(gm['GM Open']-gm['GM Open'].shift(1),gm['GM Open']), bins= 100, label = 'GM')

plt.legend()
plt.show()

# %%
plt.figure(figsize=[15,10])

sns.kdeplot(100*np.divide(ford['Ford Open']-ford['Ford Open'].shift(1),ford['Ford Open']), label = 'Ford')

sns.kdeplot(100*np.divide(tesla['Tesla Open']-tesla['Tesla Open'].shift(1),tesla['Tesla Open']), label = 'Tesla')

sns.kdeplot(100*np.divide(gm['GM Open']-gm['GM Open'].shift(1),gm['GM Open']), label = 'GM')

plt.legend()
plt.show()

# %%
sns.boxplot(100*np.divide(ford['Ford Open']-ford['Ford Open'].shift(1),ford['Ford Open']))
plt.show()
sns.boxplot(100*np.divide(tesla['Tesla Open']-tesla['Tesla Open'].shift(1),tesla['Tesla Open']))
plt.show()
sns.boxplot(100*np.divide(gm['GM Open']-gm['GM Open'].shift(1),gm['GM Open']))
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GM Open'>

# %%
tesla.head()
# Out:
#             Tesla Open   High    Low  Close   Volume   Traded Val
# Date
# 2012-01-03       28.94  29.50  27.65  28.08   928052  26857824.88
# 2012-01-04       28.21  28.67  27.50  27.71   630036  17773315.56
# 2012-01-05       27.76  27.93  26.85  27.12  1005432  27910792.32
# 2012-01-06       27.20  27.79  26.41  26.89   687081  18688603.20
# 2012-01-09       27.00  27.49  26.12  27.25   896951  24217677.00

# %%
tesla['% Daily Returns'] = np.divide(tesla['Tesla Open']-tesla.shift(1)['Tesla Open'], tesla['Tesla Open'])*100

# %%
tesla.head(20)
# Out:
#             Tesla Open   High    Low  Close   Volume    Traded Val  \
# Date
# 2012-01-03       28.94  29.50  27.65  28.08   928052  2.685782e+07
# 2012-01-04       28.21  28.67  27.50  27.71   630036  1.777332e+07
# 2012-01-05       27.76  27.93  26.85  27.12  1005432  2.791079e+07
# 2012-01-06       27.20  27.79  26.41  26.89   687081  1.868860e+07
# 2012-01-09       27.00  27.49  26.12  27.25   896951  2.421768e+07
# 2012-01-10       27.44  27.76  27.25  27.62   671732  1.843233e+07
# 2012-01-11       27.62  28.38  27.30  28.23   672239  1.856724e+07
# 2012-01-12       28.48  28.62  27.80  28.25   729300  2.077046e+07
# 2012-01-13       28.40  28.50  22.64  22.79  5506439  1.563829e+08
# 2012-01-17       26.62  27.34  26.41  26.60  4652386  1.238465e+08
# 2012-01-18       26.69  26.88  26.25  26.81  1260183  3.363428e+07
# 2012-01-19       27.19  27.74  26.61  26.76  1246222  3.388478e+07
# 2012-01-20       26.90  27.00  26.40  26.60   662289  1.781557e+07
# 2012-01-23       26.81  27.21  26.60  26.77   594533  1.593943e+07
# 2012-01-24       26.63  27.68  26.44  27.42   857914  2.284625e+07
# 2012-01-25       27.27  28.01  27.05  27.97   611112  1.666502e+07
# 2012-01-26       28.07  29.58  28.00  28.94  1271028  3.567776e+07
# 2012-01-27       28.50  29.72  28.50  29.33   748361  2.132829e+07
# 2012-01-30       29.49  29.61  28.53  29.57   728979  2.149759e+07
# 2012-01-31       29.90  30.00  28.87  29.07   956713  2.860572e+07
#
#             % Daily Returns
# Date
# 2012-01-03              NaN
# 2012-01-04        -2.587735
# 2012-01-05        -1.621037
# 2012-01-06        -2.058824
# 2012-01-09        -0.740741
# 2012-01-10         1.603499
# 2012-01-11         0.651702
# 2012-01-12         3.019663
# 2012-01-13        -0.281690
# 2012-01-17        -6.686702
# 2012-01-18         0.262271
# 2012-01-19         1.838911
# 2012-01-20        -1.078067
# 2012-01-23        -0.335696
# 2012-01-24        -0.675929
# 2012-01-25         2.346901
# 2012-01-26         2.850018
# 2012-01-27         1.508772
# 2012-01-30         3.357070
# 2012-01-31         1.371237

# %%
plt.figure(figsize = [30,20])
plt.plot(tesla['% Daily Returns'])

# %%
tesla['Cumulative Returns'] = np.divide(tesla['Tesla Open']-tesla['Tesla Open'][0], tesla['Tesla Open'][0])*100

# %%
plt.plot(tesla['Cumulative Returns'])

# %%
tesla['Tesla Open'][0]
# Out:
# 28.94

# %%
tesla['Tesla Open'].max()
# Out:
# 287.67

# %%
(287-28)/28
# Out:
# 9.25
